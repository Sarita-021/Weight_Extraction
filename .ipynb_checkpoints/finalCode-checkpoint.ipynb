# %% [markdown]
# # Importing the libraries

# %%
import os
import random
import cv2
import re
import sys
import imutils
import pytesseract
from re import A
import numpy as np
import pandas as pd
from pytesseract import Output
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image
from PIL import Image
sys.path.append('./src/') 
from img_utils import download_images

# %% [markdown]
# # Loading the datasets

# %%
DATASET_FOLDER = './dataset/'
train = pd.read_csv(os.path.join(DATASET_FOLDER, 'train.csv'))
test = pd.read_csv(os.path.join(DATASET_FOLDER, 'test.csv'))
sample_test = pd.read_csv(os.path.join(DATASET_FOLDER, 'sample_test.csv'))

# %% [markdown]
# ## Importing download_images function from img_utils

# %%
download_images(sample_test['image_link'], sample_test['group_id'], '../images')
assert len(os.listdir('../images')) > 0
# Out:
# 100%|█████████████████████████████████████████| 251/251 [00:35<00:00,  7.12it/s]

# %% [markdown]
# ### Show image function

# %%
directory_imgs = "../images/"
paths = [os.path.join(directory_imgs, f) for f in os.listdir(directory_imgs)]
# print(paths)

# %%
def show_img(img):
    fig = plt.gcf()
    fig.set_size_inches(20, 10)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
# for image in paths:
#     print(image)
#     img = cv2.imread(image)
#     show_img(img)

# %% [markdown]
# # Text Recognition

# %%
gpu = True
min_conf = 10
font = './content/calibri.ttf'
config_tesseract = "--tessdata-dir tessdata"

# %%
from easyocr import Reader
reader = Reader(['en'], gpu)

# %%
def write_text(text, x, y, img, font, color=(209, 0, 3), font_size=18):
    font = ImageFont.truetype(font, font_size)
    img_pil = Image.fromarray(img)
    draw = ImageDraw.Draw(img_pil)
    draw.text((x, y-font_size), text, font = font, fill = color)
    img = np.array(img_pil)
    return img

# %%
def box(i, result, img, color=(209, 0, 3)):
    (lt, rt, br, bl) = result[i][0]
    lt = (int(lt[0]), int(lt[1]))
    rt = (int(rt[0]), int(rt[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
    cv2.rectangle(img, lt, br, color, 2)

    return lt[0], lt[1], img

# %%
def convert_to_equi_unit(value, unit):
    """Convert different units to grams."""
    unit = unit.lower()
    if unit in ['kg', 'kilogram']:
        print(value*1000, 'g')
        return value * 1000   
    elif unit in ['g', 'gram']:
        return value  
    elif unit in ['mg', 'milligram']:
        return value / 1000 
    elif unit in ['litre', 'l']:
        return value * 1000 
    elif unit in ['ml', 'millilitre']:
        return value 
    elif unit in ['cm', 'centimetre']:
        return value / 100
    elif unit in ['mm', 'millimetre']:
        return value / 1000
    elif unit in ['m', 'metre']:
        return value
    elif unit in ['pound']:
        return value*453.6
    elif unit in ['oz', 'ounce']:
        return value*28.35
    else:
        return value  # In case of an unsupported unit

# %%
def ocr_process_img(img, config_tesseract, min_conf):
    results = reader.readtext(img)
    results = np.array(results, dtype=object)
    
    #print(results[:,1])
    print('======================================================')
    
    # Select the appropriate pattern based on the entity name
    term_search = r'\(?\d+(?:\.\d+)?\s?(kg|kilogram|g|gram|mg|milligram|lb|pound|oz|ounce|litre|ml|millilitre|gallon|cup|quart|pint|cm|centimetre|mm|millimetre|m|metre|inch|foot)\)?' 

    regex = re.compile(term_search, re.IGNORECASE)
    
    max_value = -1
    max_match = None
    max_box = None
    
    # Loop through all detected text results
    for i in range(0, len(results[:, 1])):
        texts = results[i][1]
        match = re.search(term_search, texts.lower())
        
        if match:
            obj_weight = re.search(r'\d+(?:\.\d+)?', match.group())
            val = float(obj_weight.group())  # Extract the numeric value
            match_unit = r'\(?\s?(kg|kilogram|g|gram|mg|milligram|lb|pound|oz|ounce|litre|ml|millilitre|gallon|cup|quart|pint|cm|centimetre|mm|millimetre|m|metre|inch|foot)\)?'
            entity_unit = re.search(match_unit, match.group())
            unit = entity_unit.group()  # Extract the unit
            
            value = convert_to_equi_unit(val, unit.strip())
            
            if value is not None and value > max_value :
                max_value = value
                max_match = match.group()
                max_box = (i, val, unit)  # Save box information for the max value

    # If we found a valid match with the greatest value, box it
    weight = None
    if max_box:
        i, value, unit = max_box
        weight = str(value) + " " + unit
        x, y, img = box(i, results, img, (209, 0, 3))  # Draw a box around the greatest entity
        img = write_text(max_match, x, y, img, font, (209, 0, 3), 18)  # Write the matched text

    
    return img, weight

# %%
i=0
for image in paths:
    img = cv2.imread(image)
    img_original = img.copy()
    file_image = os.path.split(image)[-1]
    print('=================\n' + str(file_image))
    
    img, max_value = ocr_process_img(img, config_tesseract, min_conf)
    if max_value is None or max_value == -1:
        print(f"No valid entity found. Deleting {file_image}")
        os.remove(image)  # Delete the image file if no valid weight is found
    else:
        print('{} of the object is {}'.format(sample_test['entity_name'][i], max_value))
        show_img(img)
    i+=1
# Out:
# =================
# 913156.jpg
# ======================================================
# entity_name of the object is 20.0  cm
# =================
# 695925.jpg
# ======================================================
# No valid entity found. Deleting 695925.jpg
# =================
# 658003.jpg
# ======================================================
# width of the object is 65.0  cm
# =================
# 900671.jpg
# ======================================================
# No valid entity found. Deleting 900671.jpg
# =================
# 478357.jpg
# ======================================================
# depth of the object is 40.0  cm
# =================
# 932012.jpg
# ======================================================
# depth of the object is 14.0 cm
# =================
# 498074.jpg
# ======================================================
# No valid entity found. Deleting 498074.jpg
# =================
# 849273.jpg
# ======================================================
# width of the object is 10.0 cm
# =================
# 823083.jpg
# ======================================================
# height of the object is 26.0 cm
# =================
# 648011.jpg
# ======================================================
# width of the object is 10.0  cm
# =================
# 801829.jpg
# ======================================================
# height of the object is 90.0  cm
# =================
# 329793.jpg
# ======================================================
# item_weight of the object is 200.0  mm
# =================
# 318770.jpg
# ======================================================
# No valid entity found. Deleting 318770.jpg
# =================
# 292475.jpg
# ======================================================
# depth of the object is 7.0 cm
# =================
# 171418.jpg
# ======================================================
# height of the object is 37.0  pound
# =================
# 630390.jpg
# ======================================================
# No valid entity found. Deleting 630390.jpg
# =================
# 752266.jpg
# ======================================================
# No valid entity found. Deleting 752266.jpg
# =================
# 507988.jpg
# ======================================================
# No valid entity found. Deleting 507988.jpg
# =================
# 462731.jpg
# ======================================================
# item_weight of the object is 20.6  cm
# =================
# 488883.jpg
# ======================================================
# wattage of the object is 660.0 lb
# =================
# 494500.jpg
# ======================================================
# No valid entity found. Deleting 494500.jpg
# =================
# 982714.jpg
# ======================================================
# width of the object is 7.0  cm
# =================
# 348551.jpg
# ======================================================
# No valid entity found. Deleting 348551.jpg
# =================
# 933453.jpg
# ======================================================
# No valid entity found. Deleting 933453.jpg
# =================
# 519155.jpg
# ======================================================
# 6000.0 g
# width of the object is 6.0 kg
# =================
# 469317.jpg
# ======================================================
# depth of the object is 35.0 g
# =================
# 521308.jpg
# ======================================================
# No valid entity found. Deleting 521308.jpg
# =================
# 635528.jpg
# ======================================================
# No valid entity found. Deleting 635528.jpg
# =================
# 442321.jpg
# ======================================================
# item_weight of the object is 110.0  cm
# =================
# 558806.jpg
# ======================================================
# item_weight of the object is 12.0  cm
# =================
# 279307.jpg
# ======================================================
# No valid entity found. Deleting 279307.jpg
# =================
# 433914.jpg
# ======================================================
# item_weight of the object is 183.0  cm
# =================
# 569206.jpg
# ======================================================
# No valid entity found. Deleting 569206.jpg
# =================
# 792578.jpg
# ======================================================
# width of the object is 90.0 cm
# =================
# 704724.jpg
# ======================================================
# depth of the object is 6.2  lb
# =================
# 751532.jpg
# ======================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 8
#       5 file_image = os.path.split(image)[-1]
#       6 print('=================\n' + str(file_image))
# ----> 8 img, max_value = ocr_process_img(img, config_tesseract, min_conf)
#       9 if max_value is None or max_value == -1:
#      10     print(f"No valid entity found. Deleting {file_image}")
#
# Cell In[17], line 18, in ocr_process_img(img, config_tesseract, min_conf)
#      15 max_box = None
#      17 # Loop through all detected text results
# ---> 18 for i in range(0, len(results[:, 1])):
#      19     texts = results[i][1]
#      20     match = re.search(term_search, texts.lower())
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# rm -rf ../images
